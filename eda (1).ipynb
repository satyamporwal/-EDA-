# %%
import pandas as pd

# %%
data = pd.read_csv("censusdata1.csv")

# %%
data.head()
# Out:
#    AGE          WORKCLASS  FNLWGT   EDUCATION  EDUCATION NUM  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         MARTIAL-STATUS          OCCUPATION    RELATIONSHIP    RACE      SEX  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    CAPITAL GAIN  CAPITAL LOSS  HOURS-PER-WEEK  NATIVE-COUNTRY  SALARY
# 0          2174             0              40   United-States   <=50K
# ...

# %%
data.shape
# Out:
# (32561, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   AGE             32561 non-null  int64
#  1   WORKCLASS       32561 non-null  object
#  2   FNLWGT          32561 non-null  int64
#  3   EDUCATION       32561 non-null  object
#  4   EDUCATION NUM   32561 non-null  int64
#  5   MARTIAL-STATUS  32561 non-null  object
#  6   OCCUPATION      32561 non-null  object
#  7   RELATIONSHIP    32561 non-null  object
#  8   RACE            32561 non-null  object
#  9   SEX             32561 non-null  object
#  10  CAPITAL GAIN    32561 non-null  int64
#  11  CAPITAL LOSS    32561 non-null  int64
#  12  HOURS-PER-WEEK  32561 non-null  int64
#  13  NATIVE-COUNTRY  32561 non-null  object
#  14  SALARY          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data1 = data.describe(include='all').T.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, AGE to SALARY
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   count   15 non-null     object
#  1   unique  9 non-null      object
#  2   top     9 non-null      object
#  3   freq    9 non-null      object
#  4   mean    6 non-null      object
#  5   std     6 non-null      object
#  6   min     6 non-null      object
#  7   25%     6 non-null      object
#  8   50%     6 non-null      object
#  9   75%     6 non-null      object
#  10  max     6 non-null      object
# dtypes: object(11)
# memory usage: 1.9+ KB

# %%
data[data.duplicated()]
# Out:
#        AGE          WORKCLASS  FNLWGT      EDUCATION  EDUCATION NUM  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# 18555   30            Private  144593        HS-grad              9
# 18698   19            Private   97261        HS-grad              9
# 21318   19            Private  138153   Some-college             10
# 21490   19            Private  146679   Some-college             10
# 21875   49            Private   31267        7th-8th              4
# 22300   25            Private  195994        1st-4th              2
# ...

# %%
data1 = data.copy()

# %%
data2 = data.copy()

# %%
data2.head()
# Out:
#    AGE          WORKCLASS  FNLWGT   EDUCATION  EDUCATION NUM  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         MARTIAL-STATUS          OCCUPATION    RELATIONSHIP    RACE      SEX  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    CAPITAL GAIN  CAPITAL LOSS  HOURS-PER-WEEK  NATIVE-COUNTRY  SALARY
# 0          2174             0              40   United-States   <=50K
# ...

# %%
data2["AGE"].unique()
# Out:
# array([39, 50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 32, 40, 34, 25, 43,
#        54, 35, 59, 56, 19, 20, 45, 22, 48, 21, 24, 57, 44, 41, 29, 18, 47,
#        46, 36, 79, 27, 67, 33, 76, 17, 55, 61, 70, 64, 71, 68, 66, 51, 58,
#        26, 60, 90, 75, 65, 77, 62, 63, 80, 72, 74, 69, 73, 81, 78, 88, 82,
#        83, 84, 85, 86, 87], dtype=int64)

# %%
data2["WORKCLASS"].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
import numpy as np
data2["WORKCLASS"]=data2["WORKCLASS"].replace(' ?',str(np.nan))

# %%
data2["EDUCATION"].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
data2["OCCUPATION"].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
data2["OCCUPATION"]=data2["OCCUPATION"].replace(' ?',str(np.nan))

# %%
data2["OCCUPATION"].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', 'nan', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
data2["SALARY"].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
data2.head(1)
# Out:
#    AGE   WORKCLASS  FNLWGT   EDUCATION  EDUCATION NUM  MARTIAL-STATUS  \
# 0   39   State-gov   77516   Bachelors             13   Never-married
#
#       OCCUPATION    RELATIONSHIP    RACE    SEX  CAPITAL GAIN  CAPITAL LOSS  \
# 0   Adm-clerical   Not-in-family   White   Male          2174             0
#
#    HOURS-PER-WEEK  NATIVE-COUNTRY  SALARY
# 0              40   United-States   <=50K

# %%
data2["NATIVE-COUNTRY"]=data2["NATIVE-COUNTRY"].replace(' ?',str(np.nan))

# %%
data2.to_csv("cleancensus_data2",index=False)

# %%
data3 = pd.read_csv("cleancensus_data2")

# %%
data3.head()
# Out:
#    AGE          WORKCLASS  FNLWGT   EDUCATION  EDUCATION NUM  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         MARTIAL-STATUS          OCCUPATION    RELATIONSHIP    RACE      SEX  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    CAPITAL GAIN  CAPITAL LOSS  HOURS-PER-WEEK  NATIVE-COUNTRY  SALARY
# 0          2174             0              40   United-States   <=50K
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   AGE             32561 non-null  int64
#  1   WORKCLASS       30725 non-null  object
#  2   FNLWGT          32561 non-null  int64
#  3   EDUCATION       32561 non-null  object
#  4   EDUCATION NUM   32561 non-null  int64
#  5   MARTIAL-STATUS  32561 non-null  object
#  6   OCCUPATION      30718 non-null  object
#  7   RELATIONSHIP    32561 non-null  object
#  8   RACE            32561 non-null  object
#  9   SEX             32561 non-null  object
#  10  CAPITAL GAIN    32561 non-null  int64
#  11  CAPITAL LOSS    32561 non-null  int64
#  12  HOURS-PER-WEEK  32561 non-null  int64
#  13  NATIVE-COUNTRY  31978 non-null  object
#  14  SALARY          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data3[data3.duplicated()]
# Out:
#        AGE          WORKCLASS  FNLWGT      EDUCATION  EDUCATION NUM  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# 18555   30            Private  144593        HS-grad              9
# 18698   19            Private   97261        HS-grad              9
# 21318   19            Private  138153   Some-college             10
# 21490   19            Private  146679   Some-college             10
# 21875   49            Private   31267        7th-8th              4
# 22300   25            Private  195994        1st-4th              2
# ...

# %%
data3 = data3.drop_duplicates()

# %%
data3
# Out:
#        AGE          WORKCLASS  FNLWGT    EDUCATION  EDUCATION NUM  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             MARTIAL-STATUS          OCCUPATION    RELATIONSHIP    RACE  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
numeric = [i for i in data3.columns if data3[i].dtype != 'O']

# %%
data3[numeric].head()
# Out:
#    AGE  FNLWGT  EDUCATION NUM  CAPITAL GAIN  CAPITAL LOSS  HOURS-PER-WEEK
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40

# %%
categorical = [i for i in data3.columns if data3[i].dtype == 'O']

# %%
data3[categorical]
# Out:
#                WORKCLASS    EDUCATION       MARTIAL-STATUS  \
# 0              State-gov    Bachelors        Never-married
# 1       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2                Private      HS-grad             Divorced
# 3                Private         11th   Married-civ-spouse
# 4                Private    Bachelors   Married-civ-spouse
# ...                  ...          ...                  ...
# 32556            Private   Assoc-acdm   Married-civ-spouse
# 32557            Private      HS-grad   Married-civ-spouse
# 32558            Private      HS-grad              Widowed
# 32559            Private      HS-grad        Never-married
# 32560       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                OCCUPATION    RELATIONSHIP    RACE      SEX  NATIVE-COUNTRY  \
# 0            Adm-clerical   Not-in-family   White     Male   United-States
# 1         Exec-managerial         Husband   White     Male   United-States
# ...

# %%
data3["SEX"].value_counts(normalize=True)*100
# Out:
#  Male      66.92381
#  Female    33.07619
# Name: SEX, dtype: float64

# %%
data3["RACE"].value_counts(normalize=True)*100
# Out:
#  White                 85.425823
#  Black                  9.595230
#  Asian-Pac-Islander     3.190214
#  Amer-Indian-Eskimo     0.955835
#  Other                  0.832898
# Name: RACE, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
for col in categorical:
    print(f"{col}:{data3[col].value_counts(normalize=True)*100}")
    print("=============================================")
# Out:
# WORKCLASS: Private             73.851015
#  Self-emp-not-inc     8.273346
#  Local-gov            6.817368
#  State-gov            4.227875
#  Self-emp-inc         3.635061
#  Federal-gov          3.126934
#  Without-pay          0.045601
#  Never-worked         0.022801
# Name: WORKCLASS, dtype: float64
# ...
# EDUCATION: HS-grad         32.252513
#  Some-college    22.380674
#  Bachelors       16.452039
#  Masters          5.292436
#  Assoc-voc        4.247472
#  11th             3.611273
#  Assoc-acdm       3.279344
#  10th             2.867505
#  7th-8th          1.982359
#  Prof-school      1.770292
#  9th              1.579740
#  12th             1.330793
#  Doctorate        1.269324
#  5th-6th          1.020377
#  1st-4th          0.510188
#  Preschool        0.153671
# Name: EDUCATION, dtype: float64
# ...
# MARTIAL-STATUS: Married-civ-spouse       46.009159
#  Never-married            32.784215
#  Divorced                 13.649076
#  Separated                 3.150260
# ...

# %%
for col in numeric:
    print(f"{col}:{data3[col].value_counts(normalize=True)*100}")
    print("=============================================")
# Out:
# AGE:36    2.759935
# 31    2.729201
# 34    2.723054
# 23    2.692320
# 33    2.689246
#         ...
# 83    0.018441
# 88    0.009220
# 85    0.009220
# 86    0.003073
# 87    0.003073
# Name: AGE, Length: 73, dtype: float64
# ...
# FNLWGT:164190    0.039955
# 123011    0.039955
# 203488    0.039955
# 148995    0.036881
# 113364    0.036881
#             ...
# 138342    0.003073
# 158040    0.003073
# 232784    0.003073
# 325573    0.003073
# 257302    0.003073
# Name: FNLWGT, Length: 21648, dtype: float64
# ...
# EDUCATION NUM:9     32.252513
# 10    22.380674
# 13    16.452039
# 14     5.292436
# 11     4.247472
# 7      3.611273
# 12     3.279344
# 6      2.867505
# 4      1.982359
# 15     1.770292
# 5      1.579740
# 8      1.330793
# 16     1.269324
# 3      1.020377
# 2      0.510188
# 1      0.153671
# Name: EDUCATION NUM, dtype: float64
# ...
# CAPITAL GAIN:0        91.664874
# 15024     1.066478
# 7688      0.872852
# 7298      0.756062
# 99999     0.488674
#            ...
# ...

# %%
sns.countplot(x = data3["SEX"] )
# Out:
# <AxesSubplot:xlabel='SEX', ylabel='count'>

# %%
sns.kdeplot(data3['CAPITAL LOSS'])
# Out:
# <AxesSubplot:xlabel='CAPITAL LOSS', ylabel='Density'>

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=data3[numeric[i]],shade=True, color='r')
    plt.xlabel(numeric[i])
    plt.tight_layout()

# %%
data3["SEX"].value_counts().plot.pie(y=data3["SEX"],figsize=(2,3),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='SEX'>

# %%
data3["FNLWGT"].value_counts().plot.pie(y=data3["FNLWGT"],figsize=(2,3),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='FNLWGT'>
